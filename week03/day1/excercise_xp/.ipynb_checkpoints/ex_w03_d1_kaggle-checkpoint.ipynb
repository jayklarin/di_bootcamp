# %% [markdown]
# 🌟Exercise 2: Dataset Loading And Initial Analysis
#
#
#
# Objective: Practice Dataset Loading From Kaggle And Initial Analysis.
#
# Task:
#
# for the following dataset : How Much Sleep Do Americans Really Get?, Global Trends in Mental Health Disorder and Credit Card Approvals.
#
# Load the dataset into Jupyter or Google Colab.
# Display the first few rows.
# Provide a brief dataset description.

# %%
import pandas as pd

# %%
df = pd.read_csv('Time Americans Spend Sleeping.csv')

# %%
df
# Out:
#      index  Year  Period  Avg hrs per day sleeping  Standard Error  \
# 0        0  2003  Annual                      8.57           0.018
# 1        1  2004  Annual                      8.55           0.026
# 2        2  2005  Annual                      8.62           0.023
# 3        3  2006  Annual                      8.63           0.024
# 4        4  2007  Annual                      8.57           0.024
# ..     ...   ...     ...                       ...             ...
# 940    940  2013  Annual                      8.83           0.085
# 941    941  2014  Annual                      8.98           0.086
# 942    942  2015  Annual                      8.83           0.074
# 943    943  2016  Annual                      8.92           0.071
# 944    944  2017  Annual                      8.81           0.091
#
#             Type of Days          Age Group  Activity    Sex
# 0               All days  15 years and over  Sleeping   Both
# 1               All days  15 years and over  Sleeping   Both
# 2               All days  15 years and over  Sleeping   Both
# 3               All days  15 years and over  Sleeping   Both
# 4               All days  15 years and over  Sleeping   Both
# ..                   ...                ...       ...    ...
# 940  Nonholiday weekdays  65 years and over  Sleeping  Women
# 941  Nonholiday weekdays  65 years and over  Sleeping  Women
# 942  Nonholiday weekdays  65 years and over  Sleeping  Women
# 943  Nonholiday weekdays  65 years and over  Sleeping  Women
# 944  Nonholiday weekdays  65 years and over  Sleeping  Women
#
# [945 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 945 entries, 0 to 944
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     945 non-null    int64
#  1   Year                      945 non-null    int64
#  2   Period                    945 non-null    object
#  3   Avg hrs per day sleeping  945 non-null    float64
#  4   Standard Error            945 non-null    float64
#  5   Type of Days              945 non-null    object
#  6   Age Group                 945 non-null    object
#  7   Activity                  945 non-null    object
#  8   Sex                       945 non-null    object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 66.6+ KB

# %%
df.describe()
# Out:
#             index         Year  Avg hrs per day sleeping  Standard Error
# count  945.000000   945.000000                945.000000      945.000000
# mean   472.000000  2010.000000                  8.806868        0.086958
# std    272.942302     4.322782                  0.545001        0.034631
# min      0.000000  2003.000000                  7.720000        0.018000
# 25%    236.000000  2006.000000                  8.360000        0.063000
# 50%    472.000000  2010.000000                  8.810000        0.084000
# 75%    708.000000  2014.000000                  9.190000        0.106000
# max    944.000000  2017.000000                 10.650000        0.228000

# %% [markdown]
# This dataset gives information aggergated by year for how long people sleep.

# %% [markdown]
# Exercise 3: Identifying Data Types
#
#
#
# Objective: Learn To Identify Different Data Types.
#
# Task:
#
# For the datasets from the previous exercise, categorize each column of it as either quantitative or qualitative and explain your reasoning.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 945 entries, 0 to 944
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     945 non-null    int64
#  1   Year                      945 non-null    int64
#  2   Period                    945 non-null    object
#  3   Avg hrs per day sleeping  945 non-null    float64
#  4   Standard Error            945 non-null    float64
#  5   Type of Days              945 non-null    object
#  6   Age Group                 945 non-null    object
#  7   Activity                  945 non-null    object
#  8   Sex                       945 non-null    object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 66.6+ KB

# %% [markdown]
#  0   index - qualitative
#
#  1   Year - quantative
#
#  2   Period - quantative
#
#  3   Avg hrs per day sleeping - quantitive
#
#  4   Standard Error - quantative
#
#  5   Type of Days - qualitative
#
#  6   Age Group - qualitative
#
#  7   Activity - qualitative
#
#  8   Sex - qualitative

# %% [markdown]
# 🌟Exercise 4: Exploring Data Types
#
#
#
# Objective: Learn About Different Types Of Data In Data Analysis.
#
# Task:
#
# Load the Iris dataset using Kaggle into a Jupyter Notebook or Google Colaboratory Notebook.
# Identify and list which columns in your dataset are qualitative and which are quantitative.
# Write a brief description of why each column is classified as qualitative or quantitative.
# Tools: Jupyter Notebook, Python with Pandas library.

# %%
iris = pd.read_csv('iris.csv')

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
#  0   Id - qualitative because the index is an arbitrary assinment not having to do with any values.  It is here for identification purposes.
#
#  2   SepalWidthCm - quantitative because it is talking about how many CM.  More is more and less is less.
#
#  3   PetalLengthCm - quantitative  because it is talking about how many CM.  More is more and less is less.
#
#  4   PetalWidthCm - quantitative  because it is talking about how many CM.  More is more and less is less.
#
#  5   Species - qualtitative because there is no inherent numerical value to a given species.  It is used for identification.  A quantitative example would be species size, small, medium and large.  There is an inherent idea of where they are in relation to one another.  m

# %% [markdown]
# 🌟Exercise 5: Basic Data Analysis With Google Colab
#
#
#
# Objective: Perform Basic Data Analysis Using Google Colab.
#
# Task:
#
# Using the same notebook from the previous exercise, perform basic data analysis tasks:
# Calculate the mean, median, and mode of a quantitative column.
# Create a simple plot (like a histogram or bar chart) to visualize the data using Matplotlib/Seaborn libraries :
# import matplotlib.pyplot as plt
# plt.plot(data['Name_column1'], data['Name_column2'])
# plt.show()
# Document your findings in the notebook.
# Tools: Google Colab, Python with Pandas and Matplotlib/Seaborn libraries.

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
print(f'The mean of the Sepal Length in the iris dataframe is {iris.SepalLengthCm.mean()}')
print(f'The median of the Sepal Length in the iris dataframe is {iris.SepalLengthCm.median()}')
print(f'The mode of the Sepal Length in the iris dataframe is {iris.SepalLengthCm.mode()}')
# Out:
# The mean of the Sepal Length in the iris dataframe is 5.843333333333334
# The median of the Sepal Length in the iris dataframe is 5.8
# The mode of the Sepal Length in the iris dataframe is 0    5.0
# Name: SepalLengthCm, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(iris['SepalLengthCm'], iris['PetalLengthCm'])
plt.show()

# %% [markdown]
# This looks pretty chaotic.  I would more like to do a scatter plot, so I'll try below

# %%
plt.scatter(iris['SepalLengthCm'], iris['PetalLengthCm'])
plt.show()

# %% [markdown]
# It looks like there is a positive correlation between the Sepal and Pedal length.

# %% [markdown]
# 🌟Exercise 6: Basic Observation Skills In Data Analysis
#
#
#
# Objective: Develop Observation Skills For Data Analysis.
#
# Task:
#
# Load the How Much Sleep Do Americans Really Get? dataset into Jupyter or Google Colab.
# Identify columns that could be interesting for a specific type of analysis (e.g., trend analysis, group comparison) and explain your choice.
# Tools: Jupyter Notebook, Python with Pandas library.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 945 entries, 0 to 944
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     945 non-null    int64
#  1   Year                      945 non-null    int64
#  2   Period                    945 non-null    object
#  3   Avg hrs per day sleeping  945 non-null    float64
#  4   Standard Error            945 non-null    float64
#  5   Type of Days              945 non-null    object
#  6   Age Group                 945 non-null    object
#  7   Activity                  945 non-null    object
#  8   Sex                       945 non-null    object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 66.6+ KB

# %% [markdown]
# I can see many useful comparisons between columns.  The first on that comes to mind is comparing Men and Women's sleep patterns, first generally, and then by age.  Next, we may want to compare Men of different age groups then Women of different age groups.  There are many more useful comparisons between columns, but this gives the gist of what we can and why we might compare.
#
# For trend analysis, we could compare between different types of days.  Perhaps people sleep more on the weekend than on weekdays or vice versa.  Maybe people sleep less during holidays.  These questions applied to our analysis can give us trends.
